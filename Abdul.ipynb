# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split

# %matplotlib inline

pd.set_option("display.max_rows", None,"display.max_columns", None)
#warnings.simplefilter(action='ignore')
#plt.style.use('seaborn')

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pd = pd.read_csv('/content/gdrive/MyDrive/msd.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-d3e163e35a76> in <module>()
# ----> 1 pd = pd.read_csv('/content/gdrive/MyDrive/msd.csv', encoding='utf-8')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
df[200:210]
# Out:
#                                       user_id             song_id  \
# 200  17aa9f6dbdf753831da8f38c71b66b64373de613  SOTGSQM12A8C13835E
# 201  17aa9f6dbdf753831da8f38c71b66b64373de613  SOWTTWF12AB017E12A
# 202  17aa9f6dbdf753831da8f38c71b66b64373de613  SOTCVEA12A6D4F9DBF
# 203  17aa9f6dbdf753831da8f38c71b66b64373de613  SORGHYR12AB017F847
# 204  17aa9f6dbdf753831da8f38c71b66b64373de613  SOSTUZH12AB0181789
# 205  17aa9f6dbdf753831da8f38c71b66b64373de613  SOQAQDK12A8C138F81
# 206  17aa9f6dbdf753831da8f38c71b66b64373de613  SOKGEOT12AB01815B2
# 207  17aa9f6dbdf753831da8f38c71b66b64373de613  SOKFJOP12AB018B475
# 208  17aa9f6dbdf753831da8f38c71b66b64373de613  SOXXSGK12AB0182E1B
# 209  17aa9f6dbdf753831da8f38c71b66b64373de613  SOEMJOV12A8C14238E
#
#                                     title  \
# 200                       Distorted Minds
# 201                 Esa Cancion Nos Salvo
# 202  Trend / Sprengkörper (Medley) (Live)
# 203                        The Unbeliever
# 204                            Paper Doll
# 205                         Gotta Go Home
# 206                            Gypsy Eyes
# 207                           Valse Lente
# 208                                 Three
# 209                              Gridlock
#
#                                                release  \
# 200                        You Don't Know - Ninja Cuts
# 201                                Manual de redencion
# 202  Mediengruppe Telekommander Live In München am ...
# 203                                    The Sun & Earth
# 204                                        The 80's EP
# 205                                  20th Century Hits
# 206                      You Break It...You Bought It!
# 207  Rossini's La Boutique Fantasque_ Dukas's The S...
# 208                                           Gymnasia
# 209                            Escalation of Hostility
#
#                      artist_name  year  listen_count
# 200  Hexstatic feat. Juice Aleem     0             1
# 201                     Travolta     0             1
# 202   Mediengruppe Telekommander     0             1
# 203       Middle Distance Runner     0             1
# 204               Denison Witmer     0             1
# 205                Boney M. 2000  1999             1
# 206         Michael Stanley Band  1975             1
# 207        Boston Pops Orchestra     0             1
# 208      The Show is the Rainbow     0             5
# 209              Kill The Client  2005             2

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a74c58233b9e> in <module>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
